# %%
import re
from nltk.tokenize import TreebankWordTokenizer
import pandas as pd
from ast import literal_eval
from collections import Counter
import nltk

# %%
stopwords = pd.read_csv('stopwords.csv')
stopwords = list(stopwords['0'])
stopwords.extend(['n','series','watch', 'watched', 'watching', 'show', 'shows', 'one','us','much','every','also','episode','netflix','show',
                  'best','ever','tv','one','two','0','1','ever','never','seen','david','see', 'must', 'really', 'story', 'even', 
                  'many', 'like', 'would', 'movie', 'movies', 'made', 'get', 'johnny', 'daniel','think', 'say', 'first', 'could', 'feel', 'film',
                  'films', 'kim', 'often', 'plot', 'episodes', 'still', 'way', 'dave', 'michael', 'review', 'bit', 'thought', 'get', 'got',
                  'make', 'makes', 'thing', 'things', 'ni', 'yet', 'another', 'other', 'going', 'second', 'third', 'sam', 'jack', 'elizabeth',
                  'give', 'get', 'go', 'henry', 'lee', 'min', 'ho', 'go', 'eun', 'hyun', 'bin', 'joel', 'kate', 'scene', 'scenes', 'yes',
                  'done', 'kristen', 'hannah', 'richard', 'always', 'especially', 'though', 'lewis', 'paul', 'know', 'knew', 'robert', 'robert', 
                  'actor', 'anderson', 'thomas', 'lot', 'character', 'characters', 'wow', 'actors', 'want', 'seems', 'seem', 'jessica', 'alex',
                  'christina', 'saw', 'actually', 'flynn', 'amy', 'tyler', 'nick', 'jake', 'steven', 'conclusion', 'hee', 'john', 'jeff', 'let',
                  'sandy', 'james', 'danny', 'ben', 'something', 'almost', 'janet', 'writing', 'kathleen', 'ellen', 'enough', 'noah', 'charlie', 
                  'nicole', 'adam', 'laura', 'use', 'need', 'type', 'ryan', 'emma', 'rizwan', 'karan', 'johar', 'mnik', 'rukh', 'chris', 'jaden', 
                  'smith', 'zwick', 'leonardo', 'johnson', 'ivan', 'andrei','oa', 'ok', 'sisko', 'odo', 'tng', 'goes', 'beth', 'natasha', 'st', 
                  'gets', 'waes', 'nd', 'stefan', 'joe', 'frank', 'storyline', 'liked', 'like', 'mindy', 'mickey', 'ram', 'aronofsky', 'marisa', 
                  'robinson', 'rachel', 'darren', 'reviews', 'anthony', 'th', 'cgi', 'leo', 'eli', 'lina', 'ricky', 'hec', 'julian', 'willem', 
                  'matt', 'jason', 'franka', 'marie', 'owen', 'clive', 'doug', 'neil', 'patrick', 'jim', 'cast', 'drew', 'timothy', 'sheila', 
                  'neelix', 'ani', 'meh', 'looking', 'part', 'nseason', 'cw', 'dick', 'robin', 'raven', 'getting', 'ratings', 'rating', 'rom', 
                  'allie', 'greta', 'jo', 'drago', 'ray', 'alan', 'abigail', 'steve', 'dano', 'greg', 'mal', 'murphy', 'eddie', 'myers', 'cameron', 
                  'cdo', 'mckay', 'brad', 'abraham', 'gus', 'judd', 'jacobs', 'someone', 'lorelai', 'luke', 'seemed', 'allen', 'sara', 'kj', 
                  'please', 'kat', 'charles', 'jenna', '0s', 'jamie', 'edward', 'aaron', 'linney', 'jennifer', 'bradley', 'tiffany', 'people',
                  'mary', 'donald', 'calvin', 'jarrett', 'craig', 'catherine', 'mlp', 'kimmy', 'tina', 'ellie', 'rd', 'jonah', '00', 'chiwetel',
                  'based', 'sebastian', 'maja', 'tim', 'ormond', 'julia', 'oliver', 'went', 'pryce', 'bergoglio', 'jonathan', 'meirelles', 'li', 
                  'huo', 'mackenzie', 'marcus', 'rables', 'mis', 'anne', 'hugh', 'del', 'toro', 'emily', 'josh', 'denis', 'melissa', 'kevin', 'ii',
                  'ayer', 'logan', 'shia', 'jon', 'labeouf', 'bernthal', 'christopher', 'jodie', 'denzel', 'russell', 'ja', 'geum', 'ae',  'baek',
                  'seth', 'evan', 'cera', 'rogen', 'tom', 'harry', 'ron', 'elliot', 'soon', 'tos', 'ds', 'marianne', 'start', 'starts', 'wes', 'platt',
                  'lange', 'main', 'aj', 'ru', 'akhtar', 'anshul', 'freddie', 'keri', 'lyla', 'since', 'sacha', 'rylance', 'abbie', 'hayden', 
                  'eva', 'tilda', 'reilly', 'lynne', 'c', 'ezra', 'michelle', 'edgar',  'charlize', 'lomax','season','seasons','sci','fi','absolutely',
                  'keep','without','last','lost','whole','acting','everything','end','else','nthe','f', 'studio','written','single','times','english',
                 'good', 'well', 'amazing', 'great', 'better', 'excellent', 'awesome', 'perfect', 'brilliant','right','perfectly','cast','years','sure',
                 'stop','k','mr','shin','rita','loved','mille','lea','probably','wish','rdis','stone','perhaps','carl','con', 'jr', 'walken', 'making',
                  'true','little','back','south','chan','wook','tae','sook','used','krabs','krusty','hillenburg','x','rw','ik','jun','pitt','ed',
                 'version','kaluuya','quite'
                 ]),
# Out:
# (None,)

# %%
pd.DataFrame(stopwords).to_csv('stopwords2.csv',encoding='utf-8')

# %%
imdb_review = pd.read_csv('imdb_review.csv',encoding='utf-8')
imdb_review.rename(columns={'Unnamed: 0':'ntitle'},inplace=True)

# %%
imdb_review
# Out:
#                     ntitle                                              title  \
# 0                우주 히어로 키드  ['so, a kid...', 'A Show Worth Watching', "Cra...
# 1     청소년 v 정부: 기후 정의를 외치다                                                 []
# 2            하프 배드: 선 & 데빌  ['Excellent movie and loved the soundtrack.', ...
# 3             Breaking Bad  ['Really Great', 'Damn near perfect!', 'Among ...
# 4                   우리의 지구  ['Wow', 'Done before, But not like this', 'Mak...
# ...                    ...                                                ...
# 1801               해피 데스데이  ['Surprisingly better than I expected!', "'Gro...
# 1802             임금님의 사건수첩  ['The king of Joseon is now a Sherlock Holmes-...
# 1803           아이 엠 브렌트 모린  ['A perspective after all the hype has died do...
# 1804                  알카티브  ['Lame? Waste of Talent? Bollocks! This is ter...
# 1805               아마겟돈 타임  ['Disengaging & Dull...', 'This brought back s...
#
# ...

# %%
i_title=imdb_review['title'].apply(literal_eval)
i_contents=imdb_review['contents'].apply(literal_eval)

# %%
#title
text=re.sub(r"[^a-zA-Z0-0]"," ",str(i_title[577][:]))
text =' '.join(text.split())

tokenizer = TreebankWordTokenizer()
tokens = tokenizer.tokenize(text.lower())

tokens = [x for x in tokens if x not in stopwords]

tf_idf = Counter(tokens)
tf_idf.most_common()[:20]
# Out:
# [('horror', 50),
#  ('thriller', 20),
#  ('peele', 14),
#  ('jordan', 11),
#  ('creepy', 9),
#  ('satire', 9),
#  ('entertaining', 8),
#  ('comedy', 8),
#  ('black', 7),
#  ('smart', 7),
#  ('racial', 7),
#  ('original', 7),
#  ('white', 6),
#  ('hype', 6),
#  ('genre', 6),
#  ('fresh', 5),
#  ('guess', 5),
#  ('funny', 5),
#  ('fun', 5),
#  ('debut', 5)]

# %%
text=re.sub(r"[^a-zA-Z0-0]"," ",str(i_contents[577][:]))
text =' '.join(text.split())

tokenizer = TreebankWordTokenizer()
tokens = tokenizer.tokenize(text.lower())

tokens = [x for x in tokens if x not in stopwords]

tf_idf = Counter(tokens)
tf_idf.most_common()[:30]
# Out:
# [('horror', 400),
#  ('peele', 293),
#  ('black', 197),
#  ('white', 150),
#  ('jordan', 144),
#  ('time', 128),
#  ('rose', 112),
#  ('comedy', 111),
#  ('parents', 111),
#  ('williams', 90),
#  ('family', 84),
#  ('girlfriend', 82),
#  ('man', 81),
#  ('thriller', 77),
#  ('social', 76),
#  ('racism', 75),
#  ('director', 74),
#  ('genre', 74),
#  ('racial', 72),
#  ('keener', 62),
#  ('allison', 61),
#  ('american', 60),
#  ('debut', 59),
#  ('tension', 59),
#  ('whitford', 54),
#  ('audience', 54),
#  ('moments', 53),
#  ('armitage', 49),
#  ('african', 48),
#  ('howery', 47)]

# %%
number_list=[]
for i in i_title:
    number_list.append(len(i))

# %%
num = pd.DataFrame(number_list)

# %%
num[num[0]>230][200:260]
# Out:
#        0
# 619  250
# 627  250
# 628  250
# 629  247
# 632  250
# 634  249
# 636  249
# 637  250
# 645  248
# 651  250
# 653  250
# 655  250
# 658  250
# 679  250
# 681  250
# 683  250
# 684  251
# 685  250
# 695  250
# 698  250
# 703  250
# 705  250
# 709  250
# 712  250
# 714  248
# 719  249
# 720  249
# 728  250
# 729  250
# 731  250
# 732  250
# 738  250
# 739  249
# 748  250
# 750  250
# 756  249
# 770  250
# 780  250
# 782  250
# 783  248
# 792  250
# 793  250
# 800  250
# 802  250
# 807  250
# 809  250
# 822  249
# 825  249
# 826  250
# 831  250
# 832  250
# 834  249
# 838  250
# 845  250
# 850  250
# 857  249
# 861  250
# 864  250
# 865  250
# 883  250

# %%
imdb_review[imdb_review['ntitle'] in '더글로리']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13516\146049011.py in <module>
# ----> 1 imdb_review[imdb_review['ntitle'] in '더글로리']
#
# TypeError: 'in <string>' requires string as left operand, not Series

# %%
for i,t in enumerate(list(imdb_review['ntitle'])):
    if 'rams' in t:
        print(i)

# %%
'우주' in list(imdb_review['ntitle'])[0]
# Out:
# True

# %%
imdb_review.iloc[550:600]
# Out:
#                    ntitle                                              title  \
# 550  익스플레인: 코로나바이러스를 해설하다  ['Very Interesting', 'Interesting show.', 'Ama...
# 551         LEGO: 시티 어드벤처  ['The best LEGO show', 'Underrated', 'Needs mo...
# 552        우리는 영원히 어리지 않다  ['A true life Horror Story that needed to be t...
# 553          틴에이지 바운티 헌터스  ['Better than expected', 'It gets better...', ...
# 554         GIMS: 온 더 레코드           ['Connaitre Gims!', 'Great Documentary']
# 555                경찰과 도둑  ['A must-see movie if ever there was one!', 'S...
# 556                    뤼팽  ['The grand debut of the master of anime', 'St...
# 557                    법정  ['Very interesting courtroom drama from India'...
# 558               기간토사우루스  ["It's alright", 'Amazing', 'My daughter loves...
# 559                 고독의 맛  ['Whole world only Taiwan can make this', 'Sad...
# 560                 더 서펀트  ['Rather good.', 'Quality.', 'Best BBC Series ...
# ...

# %%
imdb_review.tail(100)
# Out:
#                  ntitle                                              title  \
# 1706           사만타 어게인!  ['Glazed, with Sprinkles', 'A star is (re)born...
# 1707           내 이웃의 비밀  ['Another Slow Burn', 'Moral questions are rai...
# 1708           인디언 디텍티브  ['One of the Best Canadian Shows', 'Russell Pe...
# 1709  후 워즈? 쇼: 롤모델을 찾아라  ['Imagine Joan of Arc Twerking?', 'The stupidi...
# 1710                레퀴엠  ['Style and Substance.', 'Listen up...', 'Okay...
# ...                 ...                                                ...
# 1801            해피 데스데이  ['Surprisingly better than I expected!', "'Gro...
# 1802          임금님의 사건수첩  ['The king of Joseon is now a Sherlock Holmes-...
# 1803        아이 엠 브렌트 모린  ['A perspective after all the hype has died do...
# 1804               알카티브  ['Lame? Waste of Talent? Bollocks! This is ter...
# 1805            아마겟돈 타임  ['Disengaging & Dull...', 'This brought back s...
#
#                                                contents      imdbid
# ...
